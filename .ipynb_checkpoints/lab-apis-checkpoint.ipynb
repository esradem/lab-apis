# %% [markdown]
# # Lab | APIs

# %% [markdown]
# In order to use the `Spotify` API (`SpotiPy`), create an account in `Spotify` and follow [these](https://developer.spotify.com/documentation/general/guides/app-settings/) steps.

# %% [markdown]
# ## Authentication and initializing the API

# %% [markdown]
# Save your client ID and your client secret in your preferred way, and read it or load it into the following variables:

# %%
import os

# Path to your credentials file
file_path = os.path.expanduser("~/Desktop/spotify_credentials.txt")

# Read credentials into a dictionary
credentials = {}
with open(file_path, "r") as file:
    for line in file:
        key, value = line.strip().split("=")
        credentials[key] = value

# %% [markdown]
# Once you have done it, we will start initializing the API.

# %%
from spotipy.oauth2 import SpotifyClientCredentials
import spotipy

client_credentials_manager = SpotifyClientCredentials(
    client_id=credentials['CLIENT_ID'],
    client_secret=credentials['CLIENT_SECRET']
)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %% [markdown]
# ## Using the search method

# %% [markdown]
# Now, let's use the search method by introducing a "query". For example, let's try searching for "Lady Gaga":

# %%
import os

# Adjust path to your OS
file_path = os.path.expanduser("~/Desktop/spotify_credentials.txt")

# Load credentials
credentials = {}
with open(file_path, "r") as file:
    for line in file:
        line = line.strip()
        if "=" in line and not line.startswith("#"):
            key, value = line.split("=", 1)
            credentials[key.strip()] = value.strip()

# %%
results = sp.search(q='Olivia Dean', limit=1)
results
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?offset=0&limit=1&query=Olivia%20Dean&type=track',
#   'limit': 1,
#   'next': 'https://api.spotify.com/v1/search?offset=1&limit=1&query=Olivia%20Dean&type=track',
#   'offset': 0,
#   'previous': None,
#   'total': 920,
#   'items': [{'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/00x1fYSGhdqScXBRpSj3DW'},
#        'href': 'https://api.spotify.com/v1/artists/00x1fYSGhdqScXBRpSj3DW',
#        'id': '00x1fYSGhdqScXBRpSj3DW',
#        'name': 'Olivia Dean',
#        'type': 'artist',
#        'uri': 'spotify:artist:00x1fYSGhdqScXBRpSj3DW'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4laFrVqnELYYbbhwnSObNg'},
#      'href': 'https://api.spotify.com/v1/albums/4laFrVqnELYYbbhwnSObNg',
#      'id': '4laFrVqnELYYbbhwnSObNg',
#      'images': [{'height': 640,
#        'width': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2733af34b93a5eb9b68b62c6aab'},
#       {'height': 300,
#        'width': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e023af34b93a5eb9b68b62c6aab'},
#       {'height': 64,
#        'width': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048513af34b93a5eb9b68b62c6aab'}],
#      'is_playable': True,
#      'name': 'It Isn’t Perfect But It Might Be (from “Bridget Jones: Mad About the Boy” Original Motion Picture Soundtrack)',
#      'release_date': '2025-02-11',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:4laFrVqnELYYbbhwnSObNg'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/00x1fYSGhdqScXBRpSj3DW'},
#       'href': 'https://api.spotify.com/v1/artists/00x1fYSGhdqScXBRpSj3DW',
#       'id': '00x1fYSGhdqScXBRpSj3DW',
#       'name': 'Olivia Dean',
#       'type': 'artist',
#       'uri': 'spotify:artist:00x1fYSGhdqScXBRpSj3DW'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 216000,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBUM72407901'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1wsLt0uxVHxUMXfwfI6Gsn'},
#     'href': 'https://api.spotify.com/v1/tracks/1wsLt0uxVHxUMXfwfI6Gsn',
#     'id': '1wsLt0uxVHxUMXfwfI6Gsn',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'It Isn’t Perfect But It Might Be - from “Bridget Jones: Mad About the Boy” Original Motion Picture Soundtrack',
#     'popularity': 75,
#     'preview_url': None,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:1wsLt0uxVHxUMXfwfI6Gsn'}]}}

# %%
results.keys() # We can see that we only have tracks
# Out:
# dict_keys(['tracks'])

# %%
results["tracks"].keys() # Let's check the values
# Out:
# dict_keys(['href', 'limit', 'next', 'offset', 'previous', 'total', 'items'])

# %%
results["tracks"]["href"] # Query we have searched
# Out:
# 'https://api.spotify.com/v1/search?offset=0&limit=1&query=Olivia%20Dean&type=track'

# %%
results["tracks"]["items"] #items (actual tracks)
# Out:
# [{'album': {'album_type': 'single',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/00x1fYSGhdqScXBRpSj3DW'},
#      'href': 'https://api.spotify.com/v1/artists/00x1fYSGhdqScXBRpSj3DW',
#      'id': '00x1fYSGhdqScXBRpSj3DW',
#      'name': 'Olivia Dean',
#      'type': 'artist',
#      'uri': 'spotify:artist:00x1fYSGhdqScXBRpSj3DW'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/4laFrVqnELYYbbhwnSObNg'},
#    'href': 'https://api.spotify.com/v1/albums/4laFrVqnELYYbbhwnSObNg',
#    'id': '4laFrVqnELYYbbhwnSObNg',
#    'images': [{'height': 640,
#      'width': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b2733af34b93a5eb9b68b62c6aab'},
#     {'height': 300,
#      'width': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e023af34b93a5eb9b68b62c6aab'},
#     {'height': 64,
#      'width': 64,
#      'url': 'https://i.scdn.co/image/ab67616d000048513af34b93a5eb9b68b62c6aab'}],
#    'is_playable': True,
#    'name': 'It Isn’t Perfect But It Might Be (from “Bridget Jones: Mad About the Boy” Original Motion Picture Soundtrack)',
#    'release_date': '2025-02-11',
#    'release_date_precision': 'day',
#    'total_tracks': 1,
#    'type': 'album',
#    'uri': 'spotify:album:4laFrVqnELYYbbhwnSObNg'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/00x1fYSGhdqScXBRpSj3DW'},
#     'href': 'https://api.spotify.com/v1/artists/00x1fYSGhdqScXBRpSj3DW',
#     'id': '00x1fYSGhdqScXBRpSj3DW',
#     'name': 'Olivia Dean',
#     'type': 'artist',
#     'uri': 'spotify:artist:00x1fYSGhdqScXBRpSj3DW'}],
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
#    'LI',
#    'MC',
#    'ID',
#    'JP',
#    'TH',
#    'VN',
#    'RO',
#    'IL',
#    'ZA',
#    'SA',
#    'AE',
#    'BH',
#    'QA',
#    'OM',
#    'KW',
#    'EG',
#    'MA',
#    'DZ',
#    'TN',
#    'LB',
#    'JO',
#    'PS',
#    'IN',
#    'KZ',
#    'MD',
#    'UA',
#    'AL',
#    'BA',
#    'HR',
#    'ME',
#    'MK',
#    'RS',
#    'SI',
#    'KR',
#    'BD',
#    'PK',
#    'LK',
#    'GH',
#    'KE',
#    'NG',
#    'TZ',
#    'UG',
#    'AG',
#    'AM',
#    'BS',
#    'BB',
#    'BZ',
#    'BT',
#    'BW',
#    'BF',
#    'CV',
#    'CW',
#    'DM',
#    'FJ',
#    'GM',
#    'GE',
#    'GD',
#    'GW',
#    'GY',
#    'HT',
#    'JM',
#    'KI',
#    'LS',
#    'LR',
#    'MW',
#    'MV',
#    'ML',
#    'MH',
#    'FM',
#    'NA',
#    'NR',
#    'NE',
#    'PW',
#    'PG',
#    'WS',
#    'SM',
#    'ST',
#    'SN',
#    'SC',
#    'SL',
#    'SB',
#    'KN',
#    'LC',
#    'VC',
#    'SR',
#    'TL',
#    'TO',
#    'TT',
#    'TV',
#    'VU',
#    'AZ',
#    'BN',
#    'BI',
#    'KH',
#    'CM',
#    'TD',
#    'KM',
#    'GQ',
#    'SZ',
#    'GA',
#    'GN',
#    'KG',
#    'LA',
#    'MO',
#    'MR',
#    'MN',
#    'NP',
#    'RW',
#    'TG',
#    'UZ',
#    'ZW',
#    'BJ',
#    'MG',
#    'MU',
#    'MZ',
#    'AO',
#    'CI',
#    'DJ',
#    'ZM',
#    'CD',
#    'CG',
#    'IQ',
#    'LY',
#    'TJ',
#    'VE',
#    'ET',
#    'XK'],
#   'disc_number': 1,
#   'duration_ms': 216000,
#   'explicit': False,
#   'external_ids': {'isrc': 'GBUM72407901'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/1wsLt0uxVHxUMXfwfI6Gsn'},
#   'href': 'https://api.spotify.com/v1/tracks/1wsLt0uxVHxUMXfwfI6Gsn',
#   'id': '1wsLt0uxVHxUMXfwfI6Gsn',
#   'is_local': False,
#   'is_playable': True,
#   'name': 'It Isn’t Perfect But It Might Be - from “Bridget Jones: Mad About the Boy” Original Motion Picture Soundtrack',
#   'popularity': 75,
#   'preview_url': None,
#   'track_number': 1,
#   'type': 'track',
#   'uri': 'spotify:track:1wsLt0uxVHxUMXfwfI6Gsn'}]

# %%
results["tracks"]["limit"]#Limit we have chosen
# Out:
# 1

# %%
results["tracks"]["next"] #link to the next page (next 50 tracks)
# Out:
# 'https://api.spotify.com/v1/search?offset=1&limit=1&query=Olivia%20Dean&type=track'

# %%
results["tracks"]["offset"] # Actual offset (starting point)
# Out:
# 0

# %%
results["tracks"]["previous"] #Previous search

# %%
results["tracks"]["total"] # Number of matches
# Out:
# 920

# %% [markdown]
# ## Exploring the tracks

# %%
results["tracks"]["items"][0] # Explore the first song
# Out:
# {'album': {'album_type': 'single',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/00x1fYSGhdqScXBRpSj3DW'},
#     'href': 'https://api.spotify.com/v1/artists/00x1fYSGhdqScXBRpSj3DW',
#     'id': '00x1fYSGhdqScXBRpSj3DW',
#     'name': 'Olivia Dean',
#     'type': 'artist',
#     'uri': 'spotify:artist:00x1fYSGhdqScXBRpSj3DW'}],
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
#    'LI',
#    'MC',
#    'ID',
#    'JP',
#    'TH',
#    'VN',
#    'RO',
#    'IL',
#    'ZA',
#    'SA',
#    'AE',
#    'BH',
#    'QA',
#    'OM',
#    'KW',
#    'EG',
#    'MA',
#    'DZ',
#    'TN',
#    'LB',
#    'JO',
#    'PS',
#    'IN',
#    'KZ',
#    'MD',
#    'UA',
#    'AL',
#    'BA',
#    'HR',
#    'ME',
#    'MK',
#    'RS',
#    'SI',
#    'KR',
#    'BD',
#    'PK',
#    'LK',
#    'GH',
#    'KE',
#    'NG',
#    'TZ',
#    'UG',
#    'AG',
#    'AM',
#    'BS',
#    'BB',
#    'BZ',
#    'BT',
#    'BW',
#    'BF',
#    'CV',
#    'CW',
#    'DM',
#    'FJ',
#    'GM',
#    'GE',
#    'GD',
#    'GW',
#    'GY',
#    'HT',
#    'JM',
#    'KI',
#    'LS',
#    'LR',
#    'MW',
#    'MV',
#    'ML',
#    'MH',
#    'FM',
#    'NA',
#    'NR',
#    'NE',
#    'PW',
#    'PG',
#    'WS',
#    'SM',
#    'ST',
#    'SN',
#    'SC',
#    'SL',
#    'SB',
#    'KN',
#    'LC',
#    'VC',
#    'SR',
#    'TL',
#    'TO',
#    'TT',
#    'TV',
#    'VU',
#    'AZ',
#    'BN',
#    'BI',
#    'KH',
#    'CM',
#    'TD',
#    'KM',
#    'GQ',
#    'SZ',
#    'GA',
#    'GN',
#    'KG',
#    'LA',
#    'MO',
#    'MR',
#    'MN',
#    'NP',
#    'RW',
#    'TG',
#    'UZ',
#    'ZW',
#    'BJ',
#    'MG',
#    'MU',
#    'MZ',
#    'AO',
#    'CI',
#    'DJ',
#    'ZM',
#    'CD',
#    'CG',
#    'IQ',
#    'LY',
#    'TJ',
#    'VE',
#    'ET',
#    'XK'],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/4laFrVqnELYYbbhwnSObNg'},
#   'href': 'https://api.spotify.com/v1/albums/4laFrVqnELYYbbhwnSObNg',
#   'id': '4laFrVqnELYYbbhwnSObNg',
#   'images': [{'height': 640,
#     'width': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b2733af34b93a5eb9b68b62c6aab'},
#    {'height': 300,
#     'width': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e023af34b93a5eb9b68b62c6aab'},
#    {'height': 64,
#     'width': 64,
#     'url': 'https://i.scdn.co/image/ab67616d000048513af34b93a5eb9b68b62c6aab'}],
#   'is_playable': True,
#   'name': 'It Isn’t Perfect But It Might Be (from “Bridget Jones: Mad About the Boy” Original Motion Picture Soundtrack)',
#   'release_date': '2025-02-11',
#   'release_date_precision': 'day',
#   'total_tracks': 1,
#   'type': 'album',
#   'uri': 'spotify:album:4laFrVqnELYYbbhwnSObNg'},
#  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/00x1fYSGhdqScXBRpSj3DW'},
#    'href': 'https://api.spotify.com/v1/artists/00x1fYSGhdqScXBRpSj3DW',
#    'id': '00x1fYSGhdqScXBRpSj3DW',
#    'name': 'Olivia Dean',
#    'type': 'artist',
#    'uri': 'spotify:artist:00x1fYSGhdqScXBRpSj3DW'}],
#  'available_markets': ['AR',
#   'AU',
#   'AT',
#   'BE',
#   'BO',
#   'BR',
#   'BG',
#   'CA',
#   'CL',
#   'CO',
#   'CR',
#   'CY',
#   'CZ',
#   'DK',
#   'DO',
#   'DE',
#   'EC',
#   'EE',
#   'SV',
#   'FI',
#   'FR',
#   'GR',
#   'GT',
#   'HN',
#   'HK',
#   'HU',
#   'IS',
#   'IE',
#   'IT',
#   'LV',
#   'LT',
#   'LU',
#   'MY',
#   'MT',
#   'MX',
#   'NL',
#   'NZ',
#   'NI',
#   'NO',
#   'PA',
#   'PY',
#   'PE',
#   'PH',
#   'PL',
#   'PT',
#   'SG',
#   'SK',
#   'ES',
#   'SE',
#   'CH',
#   'TW',
#   'TR',
#   'UY',
#   'US',
#   'GB',
#   'AD',
#   'LI',
#   'MC',
#   'ID',
#   'JP',
#   'TH',
#   'VN',
#   'RO',
#   'IL',
#   'ZA',
#   'SA',
#   'AE',
#   'BH',
#   'QA',
#   'OM',
#   'KW',
#   'EG',
#   'MA',
#   'DZ',
#   'TN',
#   'LB',
#   'JO',
#   'PS',
#   'IN',
#   'KZ',
#   'MD',
#   'UA',
#   'AL',
#   'BA',
#   'HR',
#   'ME',
#   'MK',
#   'RS',
#   'SI',
#   'KR',
#   'BD',
#   'PK',
#   'LK',
#   'GH',
#   'KE',
#   'NG',
#   'TZ',
#   'UG',
#   'AG',
#   'AM',
#   'BS',
#   'BB',
#   'BZ',
#   'BT',
#   'BW',
#   'BF',
#   'CV',
#   'CW',
#   'DM',
#   'FJ',
#   'GM',
#   'GE',
#   'GD',
#   'GW',
#   'GY',
#   'HT',
#   'JM',
#   'KI',
#   'LS',
#   'LR',
#   'MW',
#   'MV',
#   'ML',
#   'MH',
#   'FM',
#   'NA',
#   'NR',
#   'NE',
#   'PW',
#   'PG',
#   'WS',
#   'SM',
#   'ST',
#   'SN',
#   'SC',
#   'SL',
#   'SB',
#   'KN',
#   'LC',
#   'VC',
#   'SR',
#   'TL',
#   'TO',
#   'TT',
#   'TV',
#   'VU',
#   'AZ',
#   'BN',
#   'BI',
#   'KH',
#   'CM',
#   'TD',
#   'KM',
#   'GQ',
#   'SZ',
#   'GA',
#   'GN',
#   'KG',
#   'LA',
#   'MO',
#   'MR',
#   'MN',
#   'NP',
#   'RW',
#   'TG',
#   'UZ',
#   'ZW',
#   'BJ',
#   'MG',
#   'MU',
#   'MZ',
#   'AO',
#   'CI',
#   'DJ',
#   'ZM',
#   'CD',
#   'CG',
#   'IQ',
#   'LY',
#   'TJ',
#   'VE',
#   'ET',
#   'XK'],
#  'disc_number': 1,
#  'duration_ms': 216000,
#  'explicit': False,
#  'external_ids': {'isrc': 'GBUM72407901'},
#  'external_urls': {'spotify': 'https://open.spotify.com/track/1wsLt0uxVHxUMXfwfI6Gsn'},
#  'href': 'https://api.spotify.com/v1/tracks/1wsLt0uxVHxUMXfwfI6Gsn',
#  'id': '1wsLt0uxVHxUMXfwfI6Gsn',
#  'is_local': False,
#  'is_playable': True,
#  'name': 'It Isn’t Perfect But It Might Be - from “Bridget Jones: Mad About the Boy” Original Motion Picture Soundtrack',
#  'popularity': 75,
#  'preview_url': None,
#  'track_number': 1,
#  'type': 'track',
#  'uri': 'spotify:track:1wsLt0uxVHxUMXfwfI6Gsn'}

# %%
results["tracks"]["items"][0].keys() # We will focus on album, artists, id, name, popularity, type and uri
# Out:
# dict_keys(['album', 'artists', 'available_markets', 'disc_number', 'duration_ms', 'explicit', 'external_ids', 'external_urls', 'href', 'id', 'is_local', 'is_playable', 'name', 'popularity', 'preview_url', 'track_number', 'type', 'uri'])

# %%
# Track artists
results["tracks"]["items"][0]["artists"]
# Out:
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/00x1fYSGhdqScXBRpSj3DW'},
#   'href': 'https://api.spotify.com/v1/artists/00x1fYSGhdqScXBRpSj3DW',
#   'id': '00x1fYSGhdqScXBRpSj3DW',
#   'name': 'Olivia Dean',
#   'type': 'artist',
#   'uri': 'spotify:artist:00x1fYSGhdqScXBRpSj3DW'}]

# %%
# Track artists names
for artist in results["tracks"]["items"][0]["artists"]:
    print(artist["name"])
# Out:
# Olivia Dean

# %%
# Track ID
results["tracks"]["items"][0]["id"]
# Out:
# '1wsLt0uxVHxUMXfwfI6Gsn'

# %%
# Track name
results["tracks"]["items"][0]["name"]
# Out:
# 'It Isn’t Perfect But It Might Be - from “Bridget Jones: Mad About the Boy” Original Motion Picture Soundtrack'

# %%
# Popularity index
results["tracks"]["items"][0]["popularity"]
# Out:
# 75

# %% [markdown]
# Spotify songs are identified by either a "url", a "uri", or an "id".
#
# - The `id` is an alphanumeric code, and it's the nuclear part of the identifier.
#
# - The `uri` contains "spotify:track" before the id. An uri is useful because it can be searched manually in the Spotify app.
#
# - The `url` is a link to the song on the Spotify web player.

# %%
results["tracks"]["items"][0]["uri"]
# Out:
# 'spotify:track:1wsLt0uxVHxUMXfwfI6Gsn'

# %% [markdown]
# ## Exercise 1: Discovering New Music through Your Favorite Artists
#
# **Objective:**
# Uncover new music by exploring the top tracks of your favorite artists and their related artists.
#
# **Instructions:**
#
# 1. **List Your Favorite Artists**:
#     - Make a list of your three favorite artists and store it in a variable named `artists`.
#     - Example: `artists = ["Los Fabulosos Cadillacs", "Manu Chao", "Muchachito Bombo Infierno"]`.
#
# 2. **Fetch Top Tracks**:
#     - Write a function named `get_top_tracks`.
#     - This function should accept an artist's name and return the name of the first 5 top tracks by that artist.
#     - Use the function `get_top_tracks` to get the first 5 top tracks for each artist in your `artists` list and store the results in a new list named `top_tracks_list`.
#
# 3. **Discover Related Artists**:
#     - Write a function named `find_related_artists`.
#     - This function should accept an artist's name and return the names of the first 5 artists related to the provided artist.
#     - Store the results in a list named `related_artists_list`.
#
# **Challenge:**
# Combine the above steps to create a playlist that includes the top tracks of your favorite artists and the top tracks of the artists related to them.

# %% [markdown]
# **Hint Section for 3. **Discover Related Artists**:**
#
# 1. **Getting Artist ID**:
#     - Remember that every artist on Spotify has a unique identifier: their `id`. To get the related artists, you first need to fetch the ID of the given artist.
#     - Consider using the `sp.search` method to query the artist's name. The method requires a `q` parameter, which is your query (in this case, the artist's name). It also has a `limit` parameter, which specifies the number of tracks it returns. In this case, 1 track is enough, since we just want the artist ID.
#     - Each track in the results has an associated 'artists' field. This field is a list containing details about all artists involved in that track.
#    - For most tracks, especially those by a single artist, this list will contain one artist. From this artist's details, you can extract the 'id' field, which is the unique identifier for that artist on Spotify.
#
#
# 3. **Fetching Related Artists**:
#     - Once you have the artist's ID, you can use another SpotiPy method to fetch related artists. Think about which SpotiPy method allows you to get related artists using an artist's ID. Here is the documentation link: https://spotipy.readthedocs.io/en/2.22.1/.
#     - This method will return a list of related artists. You'll need to extract the relevant details (artist names) from this list.
#
# 4. **Iterating for Multiple Artists**:
#     - Once you have a function that returns related artists names for one artist, you can use a list comprehension to apply this function to a list of artist names.
#
# 5. **Testing**:
#     - Always test your function with one artist name first. Once you're confident it works, then apply it to the entire list.
#
# Remember, the key is to break the problem down into manageable steps. Use the SpotiPy documentation as a resource to understand available methods and their return structures.

# %%
results = sp.search(q='Olivia Dean', limit=1)
results
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?offset=0&limit=1&query=Olivia%20Dean&type=track',
#   'limit': 1,
#   'next': 'https://api.spotify.com/v1/search?offset=1&limit=1&query=Olivia%20Dean&type=track',
#   'offset': 0,
#   'previous': None,
#   'total': 920,
#   'items': [{'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/00x1fYSGhdqScXBRpSj3DW'},
#        'href': 'https://api.spotify.com/v1/artists/00x1fYSGhdqScXBRpSj3DW',
#        'id': '00x1fYSGhdqScXBRpSj3DW',
#        'name': 'Olivia Dean',
#        'type': 'artist',
#        'uri': 'spotify:artist:00x1fYSGhdqScXBRpSj3DW'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4laFrVqnELYYbbhwnSObNg'},
#      'href': 'https://api.spotify.com/v1/albums/4laFrVqnELYYbbhwnSObNg',
#      'id': '4laFrVqnELYYbbhwnSObNg',
#      'images': [{'height': 640,
#        'width': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2733af34b93a5eb9b68b62c6aab'},
#       {'height': 300,
#        'width': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e023af34b93a5eb9b68b62c6aab'},
#       {'height': 64,
#        'width': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048513af34b93a5eb9b68b62c6aab'}],
#      'is_playable': True,
#      'name': 'It Isn’t Perfect But It Might Be (from “Bridget Jones: Mad About the Boy” Original Motion Picture Soundtrack)',
#      'release_date': '2025-02-11',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:4laFrVqnELYYbbhwnSObNg'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/00x1fYSGhdqScXBRpSj3DW'},
#       'href': 'https://api.spotify.com/v1/artists/00x1fYSGhdqScXBRpSj3DW',
#       'id': '00x1fYSGhdqScXBRpSj3DW',
#       'name': 'Olivia Dean',
#       'type': 'artist',
#       'uri': 'spotify:artist:00x1fYSGhdqScXBRpSj3DW'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 216000,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBUM72407901'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1wsLt0uxVHxUMXfwfI6Gsn'},
#     'href': 'https://api.spotify.com/v1/tracks/1wsLt0uxVHxUMXfwfI6Gsn',
#     'id': '1wsLt0uxVHxUMXfwfI6Gsn',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'It Isn’t Perfect But It Might Be - from “Bridget Jones: Mad About the Boy” Original Motion Picture Soundtrack',
#     'popularity': 75,
#     'preview_url': None,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:1wsLt0uxVHxUMXfwfI6Gsn'}]}}

# %% [markdown]
# artist_related_artists(artist_id)
# Get Spotify catalog information about artists similar to an identified artist. Similarity is based on analysis of the Spotify community’s listening history.
#
# Parameters:
# artist_id - the artist ID, URI or URL
#
# artist_top_tracks(artist_id, country='US')
# Get Spotify catalog information about an artist’s top 10 tracks by country.
#
# Parameters:
# artist_id - the artist ID, URI or URL
#
# country - limit the response to one particular country.

# %%
# Fetch Top Tracks:

# Write a function named get_top_tracks.
# This function should accept an artist's name and return the name of the first 5 top tracks by that artist.
# Use the function get_top_tracks to get the first 5 top tracks for each artist in your artists list and store the results in a new list named top_tracks_list.
# Function to get top tracks

# Favorite artists
artists = ["Olivia Dean", "Leon Bridges", "Tame Impala"]

# Function to get top tracks
def get_top_tracks(artists):
    top_tracks_list = []

    for artist_name in artists:
        result = sp.search(q=artist_name, type='artist', limit=1)
        if result['artists']['items']:
            artist_id = result['artists']['items'][0]['id']
            top_tracks = sp.artist_top_tracks(artist_id, country='US')
            track_names = [track['name'] for track in top_tracks['tracks'][:5]]
            top_tracks_list.append({'artist': artist_name, 'top_tracks': track_names})
        else:
            top_tracks_list.append({'artist': artist_name, 'top_tracks': ['Artist not found']})

    return top_tracks_list

# Run the function
top_tracks_list = get_top_tracks(artists)

# Print the results
for item in top_tracks_list:
    print(f"\nTop tracks for {item['artist']}:")
    for track in item['top_tracks']:
        print(f"  - {track}")
# Out:
# Top tracks for Olivia Dean:
#   - Dive
#   - The Hardest Part
#   - Ok Love You Bye
#   - It Isn’t Perfect But It Might Be - from “Bridget Jones: Mad About the Boy” Original Motion Picture Soundtrack
#   - The Hardest Part (feat. Leon Bridges)
#
# Top tracks for Leon Bridges:
#   - Texas Sun
#   - River
#   - Coming Home
#   - Beyond
#   - Mariella
#
# Top tracks for Tame Impala:
#   - The Less I Know The Better
#   - Borderline
#   - Let It Happen
#   - New Person, Same Old Mistakes
#   - Eventually

# %%
def get_artist_id(artist_name):
    result = sp.search(q=artist_name, type='artist', limit=1)
    if result['artists']['items']:
        return result['artists']['items'][0]['id']
    return None

# Step 2: Get related artists
def get_related_artists(artist_name):
    artist_id = get_artist_id(artist_name)
    if artist_id:
        related = sp.artist_related_artists(artist_id)
        return [artist['name'] for artist in related['artists']]
    else:
        return ["Artist not found"]

# Example usage
related = get_related_artists("Tame Impala")
print("Related artists:", related)
# Out:
# HTTP Error for GET to https://api.spotify.com/v1/artists/5INjqkS1o8h1imAzPqGZBb/related-artists with Params: {} returned 404 due to Not Found
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.12/site-packages/spotipy/client.py:274, in Spotify._internal_call(self, method, url, payload, params)
#     269 response = self._session.request(
#     270     method, url, headers=headers, proxies=self.proxies,
#     271     timeout=self.requests_timeout, **args
#     272 )
# --> 274 response.raise_for_status()
#     275 results = response.json()
#
# File /opt/anaconda3/lib/python3.12/site-packages/requests/models.py:1024, in Response.raise_for_status(self)
#    1023 if http_error_msg:
# -> 1024     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 404 Client Error: Not Found for url: https://api.spotify.com/v1/artists/5INjqkS1o8h1imAzPqGZBb/related-artists
#
# During handling of the above exception, another exception occurred:
#
# SpotifyException                          Traceback (most recent call last)
# Cell In[102], line 17
#      14         return ["Artist not found"]
#      16 # Example usage
# ---> 17 related = get_related_artists("Tame Impala")
#      18 print("Related artists:", related)
#
# Cell In[102], line 11, in get_related_artists(artist_name)
#       9 artist_id = get_artist_id(artist_name)
#      10 if artist_id:
# ---> 11     related = sp.artist_related_artists(artist_id)
#      12     return [artist['name'] for artist in related['artists']]
#      13 else:
#
# File /opt/anaconda3/lib/python3.12/site-packages/spotipy/client.py:464, in Spotify.artist_related_artists(self, artist_id)
#     458 warnings.warn(
#     459     "You're using `artist_related_artists(...)`, "
#     460     "which is marked as deprecated by Spotify.",
#     461     DeprecationWarning
#     462 )
#     463 trid = self._get_id("artist", artist_id)
# --> 464 return self._get("artists/" + trid + "/related-artists")
#
# File /opt/anaconda3/lib/python3.12/site-packages/spotipy/client.py:324, in Spotify._get(self, url, args, payload, **kwargs)
#     321 if args:
#     322     kwargs.update(args)
# --> 324 return self._internal_call("GET", url, payload, kwargs)
#
# File /opt/anaconda3/lib/python3.12/site-packages/spotipy/client.py:294, in Spotify._internal_call(self, method, url, payload, params)
#     289         reason = None
#     291     logger.error(f"HTTP Error for {method} to {url} with Params: "
#     292                  f"{args.get('params')} returned {response.status_code} due to {msg}")
# --> 294     raise SpotifyException(
#     295         response.status_code,
#     296         -1,
#     297         f"{response.url}:\n {msg}",
#     298         reason=reason,
#     299         headers=response.headers,
#     300     )
#     301 except requests.exceptions.RetryError as retry_error:
#     302     request = retry_error.request
#
# SpotifyException: http status: 404, code: -1 - https://api.spotify.com/v1/artists/5INjqkS1o8h1imAzPqGZBb/related-artists:
#  Not Found, reason: None

# %% [markdown]
# ## Playlists
#
# The `sp.featured_playlists()` method in `spotipy` fetches a list of Spotify's featured playlists at a given moment. These are curated playlists that Spotify often highlights on the platform's homepage. The method provides a snapshot of the playlists that are being promoted or featured by Spotify at the time of the request.
#
# Once you've fetched the featured playlists, you can extract their IDs (and other details).

# %%
import spotipy
from spotipy.oauth2 import SpotifyOAuth

sp = spotipy.Spotify(auth_manager=SpotifyOAuth(
    client_id=credentials['CLIENT_ID'],
    client_secret=credentials['CLIENT_SECRET'],
    redirect_uri='http://127.0.0.1:8081/callback',
    scope='user-read-private',
    open_browser=True  # Ensures browser opens for login
))

# %%
# Fetch featured playlists (you can also specify country, locale, timestamp, etc.)
featured = sp.featured_playlists(limit=10)
# for playlist in featured['playlists']['items']:
#     print(f"{playlist['name']} - {playlist['external_urls']['spotify']}")
# Out:
# HTTP Error for GET to https://api.spotify.com/v1/browse/featured-playlists with Params: {'locale': None, 'country': None, 'timestamp': None, 'limit': 10, 'offset': 0} returned 404 due to Not Found
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.12/site-packages/spotipy/client.py:274, in Spotify._internal_call(self, method, url, payload, params)
#     269 response = self._session.request(
#     270     method, url, headers=headers, proxies=self.proxies,
#     271     timeout=self.requests_timeout, **args
#     272 )
# --> 274 response.raise_for_status()
#     275 results = response.json()
#
# File /opt/anaconda3/lib/python3.12/site-packages/requests/models.py:1024, in Response.raise_for_status(self)
#    1023 if http_error_msg:
# -> 1024     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 404 Client Error: Not Found for url: https://api.spotify.com/v1/browse/featured-playlists?limit=10&offset=0
#
# During handling of the above exception, another exception occurred:
#
# SpotifyException                          Traceback (most recent call last)
# Cell In[98], line 2
#       1 # Fetch featured playlists (you can also specify country, locale, timestamp, etc.)
# ----> 2 featured = sp.featured_playlists(limit=10)
#
# File /opt/anaconda3/lib/python3.12/site-packages/spotipy/client.py:1595, in Spotify.featured_playlists(self, locale, country, timestamp, limit, offset)
#    1569 """ Get a list of Spotify featured playlists
#    1570
#    1571     Parameters:
#    (...)
#    1588           items.
#    1589 """
#    1590 warnings.warn(
#    1591     "You're using `featured_playlists(...)`, "
#    1592     "which is marked as deprecated by Spotify.",
#    1593     DeprecationWarning,
#    1594 )
# -> 1595 return self._get(
#    1596     "browse/featured-playlists",
#    1597     locale=locale,
#    1598     country=country,
#    1599     timestamp=timestamp,
#    1600     limit=limit,
#    1601     offset=offset,
#    1602 )
#
# File /opt/anaconda3/lib/python3.12/site-packages/spotipy/client.py:324, in Spotify._get(self, url, args, payload, **kwargs)
#     321 if args:
#     322     kwargs.update(args)
# --> 324 return self._internal_call("GET", url, payload, kwargs)
#
# File /opt/anaconda3/lib/python3.12/site-packages/spotipy/client.py:294, in Spotify._internal_call(self, method, url, payload, params)
#     289         reason = None
#     291     logger.error(f"HTTP Error for {method} to {url} with Params: "
#     292                  f"{args.get('params')} returned {response.status_code} due to {msg}")
# --> 294     raise SpotifyException(
#     295         response.status_code,
#     296         -1,
#     297         f"{response.url}:\n {msg}",
#     298         reason=reason,
#     299         headers=response.headers,
#     300     )
#     301 except requests.exceptions.RetryError as retry_error:
#     302     request = retry_error.request
#
# SpotifyException: http status: 404, code: -1 - https://api.spotify.com/v1/browse/featured-playlists?limit=10&offset=0:
#  Not Found, reason: None

# %% [markdown]
# ### Getting a Playlist's Details
# To fetch details about a specific playlist, you can use the playlist method. You'll need the playlist's Spotify ID.

# %% [markdown]
# In this example, we will use the following playlist id: *37i9dQZF1DXd9zR7tdziuQ*

# %%
playlist_id = "37i9dQZF1DXd9zR7tdziuQ"
playlist = sp.playlist(playlist_id)
# Out:
# HTTP Error for GET to https://api.spotify.com/v1/playlists/37i9dQZF1DXd9zR7tdziuQ with Params: {'fields': None, 'market': None, 'additional_types': 'track'} returned 404 due to Resource not found
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.12/site-packages/spotipy/client.py:274, in Spotify._internal_call(self, method, url, payload, params)
#     269 response = self._session.request(
#     270     method, url, headers=headers, proxies=self.proxies,
#     271     timeout=self.requests_timeout, **args
#     272 )
# --> 274 response.raise_for_status()
#     275 results = response.json()
#
# File /opt/anaconda3/lib/python3.12/site-packages/requests/models.py:1024, in Response.raise_for_status(self)
#    1023 if http_error_msg:
# -> 1024     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 404 Client Error: Not Found for url: https://api.spotify.com/v1/playlists/37i9dQZF1DXd9zR7tdziuQ?additional_types=track
#
# During handling of the above exception, another exception occurred:
#
# SpotifyException                          Traceback (most recent call last)
# Cell In[38], line 2
#       1 playlist_id = "37i9dQZF1DXd9zR7tdziuQ"
# ----> 2 playlist = sp.playlist(playlist_id)
#
# File /opt/anaconda3/lib/python3.12/site-packages/spotipy/client.py:668, in Spotify.playlist(self, playlist_id, fields, market, additional_types)
#     657 """ Gets playlist by id.
#     658
#     659     Parameters:
#    (...)
#     665                              valid types are: track and episode
#     666 """
#     667 plid = self._get_id("playlist", playlist_id)
# --> 668 return self._get(
#     669     f"playlists/{plid}",
#     670     fields=fields,
#     671     market=market,
#     672     additional_types=",".join(additional_types),
#     673 )
#
# File /opt/anaconda3/lib/python3.12/site-packages/spotipy/client.py:324, in Spotify._get(self, url, args, payload, **kwargs)
#     321 if args:
#     322     kwargs.update(args)
# --> 324 return self._internal_call("GET", url, payload, kwargs)
#
# File /opt/anaconda3/lib/python3.12/site-packages/spotipy/client.py:294, in Spotify._internal_call(self, method, url, payload, params)
#     289         reason = None
#     291     logger.error(f"HTTP Error for {method} to {url} with Params: "
#     292                  f"{args.get('params')} returned {response.status_code} due to {msg}")
# --> 294     raise SpotifyException(
#     295         response.status_code,
#     296         -1,
#     297         f"{response.url}:\n {msg}",
#     298         reason=reason,
#     299         headers=response.headers,
#     300     )
#     301 except requests.exceptions.RetryError as retry_error:
#     302     request = retry_error.request
#
# SpotifyException: http status: 404, code: -1 - https://api.spotify.com/v1/playlists/37i9dQZF1DXd9zR7tdziuQ?additional_types=track:
#  Resource not found, reason: None

# %%
print(playlist['name'])  # Print the playlist's name
print(playlist['description'])  # Print the playlist's description
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 print(playlist['name'])  # Print the playlist's name
#       2 print(playlist['description'])
#
# NameError: name 'playlist' is not defined

# %% [markdown]
# ### Getting Tracks from a Playlist
# If you want to get the tracks from a specific playlist, you can use the playlist_tracks method.

# %%
tracks = sp.playlist_tracks(playlist_id)
for track in tracks['items']:
    print(track['track']['name'])  # Print each track's name
# Out:
# HTTP Error for GET to https://api.spotify.com/v1/playlists/37i9dQZF1DXd9zR7tdziuQ/tracks with Params: {'limit': 100, 'offset': 0, 'fields': None, 'market': None, 'additional_types': 'track'} returned 404 due to Resource not found
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.12/site-packages/spotipy/client.py:274, in Spotify._internal_call(self, method, url, payload, params)
#     269 response = self._session.request(
#     270     method, url, headers=headers, proxies=self.proxies,
#     271     timeout=self.requests_timeout, **args
#     272 )
# --> 274 response.raise_for_status()
#     275 results = response.json()
#
# File /opt/anaconda3/lib/python3.12/site-packages/requests/models.py:1024, in Response.raise_for_status(self)
#    1023 if http_error_msg:
# -> 1024     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 404 Client Error: Not Found for url: https://api.spotify.com/v1/playlists/37i9dQZF1DXd9zR7tdziuQ/tracks?limit=100&offset=0&additional_types=track
#
# During handling of the above exception, another exception occurred:
#
# SpotifyException                          Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 tracks = sp.playlist_tracks(playlist_id)
#       2 for track in tracks['items']:
#       3     print(track['track']['name'])
#
# File /opt/anaconda3/lib/python3.12/site-packages/spotipy/client.py:700, in Spotify.playlist_tracks(self, playlist_id, fields, limit, offset, market, additional_types)
#     684 """ Get full details of the tracks of a playlist.
#     685
#     686     Parameters:
#    (...)
#     693                              valid types are: track and episode
#     694 """
#     695 warnings.warn(
#     696     "You should use `playlist_items(playlist_id, ...,"
#     697     "additional_types=('track',))` instead",
#     698     DeprecationWarning,
#     699 )
# --> 700 return self.playlist_items(playlist_id, fields, limit, offset,
#     701                            market, additional_types)
#
# File /opt/anaconda3/lib/python3.12/site-packages/spotipy/client.py:724, in Spotify.playlist_items(self, playlist_id, fields, limit, offset, market, additional_types)
#     712 """ Get full details of the tracks and episodes of a playlist.
#     713
#     714     Parameters:
#    (...)
#     721                              valid types are: track and episode
#     722 """
#     723 plid = self._get_id("playlist", playlist_id)
# --> 724 return self._get(
#     725     f"playlists/{plid}/tracks",
#     726     limit=limit,
#     727     offset=offset,
#     728     fields=fields,
#     729     market=market,
#     730     additional_types=",".join(additional_types)
#     731 )
#
# File /opt/anaconda3/lib/python3.12/site-packages/spotipy/client.py:324, in Spotify._get(self, url, args, payload, **kwargs)
#     321 if args:
#     322     kwargs.update(args)
# --> 324 return self._internal_call("GET", url, payload, kwargs)
#
# File /opt/anaconda3/lib/python3.12/site-packages/spotipy/client.py:294, in Spotify._internal_call(self, method, url, payload, params)
#     289         reason = None
#     291     logger.error(f"HTTP Error for {method} to {url} with Params: "
#     292                  f"{args.get('params')} returned {response.status_code} due to {msg}")
# --> 294     raise SpotifyException(
#     295         response.status_code,
#     296         -1,
#     297         f"{response.url}:\n {msg}",
#     298         reason=reason,
#     299         headers=response.headers,
#     300     )
#     301 except requests.exceptions.RetryError as retry_error:
#     302     request = retry_error.request
#
# SpotifyException: http status: 404, code: -1 - https://api.spotify.com/v1/playlists/37i9dQZF1DXd9zR7tdziuQ/tracks?limit=100&offset=0&additional_types=track:
#  Resource not found, reason: None

# %% [markdown]
# ### Getting Artists from a Playlist
#
# To extract all the artists from the tracks in a playlist, you'd typically follow these steps:
#
# 1. Fetch the playlist's tracks.
# 2. Iterate through each track.
# 3. For each track, extract the associated artists.

# %%
# List to store unique artist names
artists_list = []

for track_item in tracks['items']:
    track = track_item['track']
    for artist in track['artists']:
        artist_name = artist['name']
        if artist_name not in artists_list:  # This ensures each artist is added only once
            artists_list.append(artist_name)

print(artists_list)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[100], line 4
#       1 # List to store unique artist names
#       2 artists_list = []
# ----> 4 for track_item in tracks['items']:
#       5     track = track_item['track']
#       6     for artist in track['artists']:
#
# NameError: name 'tracks' is not defined

# %% [markdown]
# ## Exercise 2: Unraveling the World of Playlists
#
#
# 1. **Featured Exploration**:
#    - Fetch the list of Spotify's current featured playlists.
#    - Extract and display the names and IDs of the top 5 featured playlists.
#
# 2. **Deep Dive**:
#    - Choose any one of the top 5 featured playlists (you can choose the one you personally find most interesting or simply pick one randomly).
#    - Fetch and display its name, description, and total track count.
#
# 3. **Track-tastic**:
#    - Extract and display the names of the first 10 tracks in the chosen playlist.
#
# 4. **Artistic Flair**:
#    - Create a dictionary where the keys are the names of the first 10 tracks, and the values are lists containing the names of the artists associated with each track.
#    - For example: `{"TrackName1": ["Artist1", "Artist2"], "TrackName2": ["Artist3"]}`

# %%
featured = sp.featured_playlists(limit=5)
top_playlists = featured['playlists']['items']

print("🎧 Top 5 Featured Playlists:")
for i, playlist in enumerate(top_playlists, 1):
    print(f"{i}. {playlist['name']} — ID: {playlist['id']}")

# Step 2: Deep Dive into a Playlist (pick the first one)
chosen_playlist = top_playlists[0]  # or choose another index 0–4
playlist_id = chosen_playlist['id']
playlist_details = sp.playlist(playlist_id)

print("\n🧠 Deep Dive:")
print(f"Name: {playlist_details['name']}")
print(f"Description: {playlist_details['description']}")
print(f"Total tracks: {playlist_details['tracks']['total']}")

# Step 3: Track-tastic (First 10 Tracks)
tracks = playlist_details['tracks']['items'][:10]
print("\n🎵 First 10 Tracks:")
for i, item in enumerate(tracks, 1):
    track = item['track']
    print(f"{i}. {track['name']}")

# Step 4: Artistic Flair (Track–Artist Dictionary)
track_artist_dict = {}
for item in tracks:
    track = item['track']
    track_name = track['name']
    artist_names = [artist['name'] for artist in track['artists']]
    track_artist_dict[track_name] = artist_names

print("\n🎨 Track to Artists Dictionary:")
for track, artists in track_artist_dict.items():
    print(f"{track}: {artists}")
# Out:
# HTTP Error for GET to https://api.spotify.com/v1/browse/featured-playlists with Params: {'locale': None, 'country': None, 'timestamp': None, 'limit': 5, 'offset': 0} returned 404 due to Not Found
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.12/site-packages/spotipy/client.py:274, in Spotify._internal_call(self, method, url, payload, params)
#     269 response = self._session.request(
#     270     method, url, headers=headers, proxies=self.proxies,
#     271     timeout=self.requests_timeout, **args
#     272 )
# --> 274 response.raise_for_status()
#     275 results = response.json()
#
# File /opt/anaconda3/lib/python3.12/site-packages/requests/models.py:1024, in Response.raise_for_status(self)
#    1023 if http_error_msg:
# -> 1024     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 404 Client Error: Not Found for url: https://api.spotify.com/v1/browse/featured-playlists?limit=5&offset=0
#
# During handling of the above exception, another exception occurred:
#
# SpotifyException                          Traceback (most recent call last)
# Cell In[104], line 1
# ----> 1 featured = sp.featured_playlists(limit=5)
#       2 top_playlists = featured['playlists']['items']
#       4 print("🎧 Top 5 Featured Playlists:")
#
# File /opt/anaconda3/lib/python3.12/site-packages/spotipy/client.py:1595, in Spotify.featured_playlists(self, locale, country, timestamp, limit, offset)
#    1569 """ Get a list of Spotify featured playlists
#    1570
#    1571     Parameters:
#    (...)
#    1588           items.
#    1589 """
#    1590 warnings.warn(
#    1591     "You're using `featured_playlists(...)`, "
#    1592     "which is marked as deprecated by Spotify.",
#    1593     DeprecationWarning,
#    1594 )
# -> 1595 return self._get(
#    1596     "browse/featured-playlists",
#    1597     locale=locale,
#    1598     country=country,
#    1599     timestamp=timestamp,
#    1600     limit=limit,
#    1601     offset=offset,
#    1602 )
#
# File /opt/anaconda3/lib/python3.12/site-packages/spotipy/client.py:324, in Spotify._get(self, url, args, payload, **kwargs)
#     321 if args:
#     322     kwargs.update(args)
# --> 324 return self._internal_call("GET", url, payload, kwargs)
#
# File /opt/anaconda3/lib/python3.12/site-packages/spotipy/client.py:294, in Spotify._internal_call(self, method, url, payload, params)
#     289         reason = None
#     291     logger.error(f"HTTP Error for {method} to {url} with Params: "
#     292                  f"{args.get('params')} returned {response.status_code} due to {msg}")
# --> 294     raise SpotifyException(
#     295         response.status_code,
#     296         -1,
#     297         f"{response.url}:\n {msg}",
#     298         reason=reason,
#     299         headers=response.headers,
#     300     )
#     301 except requests.exceptions.RetryError as retry_error:
#     302     request = retry_error.request
#
# SpotifyException: http status: 404, code: -1 - https://api.spotify.com/v1/browse/featured-playlists?limit=5&offset=0:
#  Not Found, reason: None
